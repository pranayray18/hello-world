# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweets_data_path = 'tbd2.txt'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
print(len(tweets_data))
# Out:
# 112

# %%
tweets = pd.DataFrame()

# %%
tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)

# %%
tweets['lang'] = list(map(lambda tweet: tweet['lang'], tweets_data))
# tweets['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
tweets['country'] = list(map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data))

# %%
tweets_by_lang = tweets['lang'].value_counts()
print(tweets_by_lang)

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')
# Out:
# en     79
# fr     10
# ja      6
# es      5
# it      3
# und     2
# et      1
# zh      1
# ko      1
# de      1
# tr      1
# ca      1
# th      1
# Name: lang, dtype: int64

# %%
tweets_by_country = tweets['country'].value_counts()
print(tweets_by_country)

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')
# Out:
# United States    1
# Sverige          1
# Name: country, dtype: int64

# %%
tweets['text'] = list(map(lambda tweet: tweet['text'], tweets_data))

# %%
# Out:
# 0      RT @pyistanbul: Python Saati #55 etkinliğimize...
# 1      Boost your #datascience skills. Learn linear a...
# 2      RT @Ronald_vanLoon: Boost your #datascience sk...
# 3      RT @ruby_redsky: crystal &amp; leaf ear cuffs ...
# 4      How to interface keypad with Raspberry Pi http...
# 5      RT @ruby_redsky: glow in the dark fishing lure...
# 6      #Curso: Javascript para Principiantes https://...
# 7      #Curso: Javascript para Principiantes https://...
# 8      #Curso: Javascript para Principiantes https://...
# 9      RT @Ronald_vanLoon: Naive Bayes #Classificatio...
# 10     RT @ruby_redsky: Fantastic stiff middle finger...
# 11     #médiassociaux L’outil de test du Mobile-Frien...
# 12     RT @ruby_redsky: #yingyang #bestfriends https:...
# 13     @sainsburys They are priced at £1.40 and have ...
# 14     @python NowTime: 2018/05/10 18:20:20.3613\nTwe...
# 15     RT @ruby_redsky: Mud make up brush https://t.c...
# 16     RT @res_tin: TDD가 무엇인지 제대로 보여준다. Flask app을 예로...
# 17     RT @ruby_redsky: earrings #fashion #statement ...
# 18     RT @kynnsk: nivea สี ruby red ลิปสีเดียวกับที่...
# 19     RT @googlewmc: For developers of JavaScript si...
# 20     RT @showprep_de: #RT @terminvorschau: DAILY #t...
# 21     Protect your furniture from #cat and #dog claw...
# 22     RT @ruby_redsky: self heating neck pain relief...
# 23     RT @ruby_redsky: Protect your furniture from #...
# 24     RT @ruby_redsky: rhinestone wing cross https:/...
# 25     @marantz_europe Ken Ishiwata ready to demo the...
# 26     L’outil de test du Mobile-Friendly analyse les...
# 27     RT @ruby_redsky: triangle slave chain bracelet...
# 28     11 Awesome Free Paper Texture Downloads #resou...
# 29     Ex : Les gens qui achètent un Python et qui se...
#                              ...
# 82     #Python3 で数列。奇数の列、階差数列、定数列。(Python 3: リスト内包表記)...
# 83     Beyond Data Science - Unit testing\n\n☞ https:...
# 84     RT @Ronald_vanLoon: Naive Bayes #Classificatio...
# 85     RT @wingwire_: how it FEELS to play #pokemon r...
# 86     #appdev Writing a simple text based #RPG in #P...
# 87     @nscmnto Flask feels alot like bare simple pyt...
# 88     RT @dlondero: "Node Microservices - the defini...
# 89     The Modern #Python 3 #Bootcamp\n\nDesigned for...
# 90     Beyond Data Science - Unit testing\n\n☞ https:...
# 91             Python٩(๑❛ᴗ❛๑)۶❤️ https://t.co/teajDS2fjb
# 92     Finding a place to deploy my new python packag...
# 93     RT @blackstock000: The Monty Python view of br...
# 94     セキュリティ問題はソフトウェアではなく、ハードウェアで解決するのが望ましい。Stroustr...
# 95     #seo : L’outil de test du Mobile-Friendly anal...
# 96     RT @EmekaGift: Today one of the victim of Oper...
# 97     Backdoored Python Library Caught Stealing SSH ...
# 98       Direi che é definitiva. https://t.co/TtB76eezwp
# 99                     @VincentSunnnnnn c# 或者 python 也行～
# 100    RT @MalwareJake: After adding JavaScript to Ex...
# 101    RT @owoFreddyFnafhs: COMO QUE ZAFIRO DEJO A RU...
# 102    RT @abhijitpanda: “Difference between Python a...
# 103    Meet Ruby the canadoodle choosing some fabric ...
# 104    FECES. SHE IS THE TASTE MADE A CONSTIPATED CLO...
# 105    How can i prepare nested key value pair list i...
# 106    ちょっとpythonやって機械学習やったぐらいじゃ絶対に儲かるレベルには来れないからとうぶん...
# 107    "Boost your #datascience skills. Learn linear ...
# 108    Designed for anyone who wants to learn Python....
# 109                          Nah https://t.co/pAOsDssdeG
# 110    RT @wingwire_: how it FEELS to play #pokemon r...
# 111    RT @seneca1900: Il paradosso che stiamo vivend...
# Name: text, Length: 112, dtype: object

# %%
data=tweets['text']

# %%
print(data.head())
# Out:
# 0    RT @pyistanbul: Python Saati #55 etkinliğimize...
# 1    Boost your #datascience skills. Learn linear a...
# 2    RT @Ronald_vanLoon: Boost your #datascience sk...
# 3    RT @ruby_redsky: crystal &amp; leaf ear cuffs ...
# 4    How to interface keypad with Raspberry Pi http...
# Name: text, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
lines = data.values.tolist()
line = ''.join(str(e) for e in lines)

# %%
wordcloud = WordCloud(width=1600, height=800).generate(line)

# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
plt.savefig('final.png', facecolor='k', bbox_inches='tight')
